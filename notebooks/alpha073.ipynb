# %% [markdown]
# ### Import & Process data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# 导入 alpha_utils 模块中的函数
import sys
from pathlib import Path
project_dir = Path().resolve().parent
sys.path.append(str(project_dir))
from alpha_utils import *

sns.set_style('whitegrid')
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# d:\miniconda3\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.0)
#   from scipy.stats import gaussian_kde

# %%
data = pd.read_pickle('../data/merged_df.pkl')
print(f"# Symbols: {len(data.index.unique('symbol')):,.0f} | # Dates: {len(data.index.unique('Date')):,.0f}")
data.info()
# Out:
# # Symbols: 20 | # Dates: 6,769
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 182763 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Open          182763 non-null  float64
#  1   High          182763 non-null  float64
#  2   Low           182763 non-null  float64
#  3   Close         182763 non-null  float64
#  4   Volume        182763 non-null  float64
#  5   id            175994 non-null  object
#  6   symbol_meta   175994 non-null  object
#  7   name          175994 non-null  object
#  8   market_cap    175994 non-null  float64
#  9   total_volume  175994 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 14.5+ MB

# %%
print("Symbols include: ", list(data.index.levels[0]))
# Out:
# Symbols include:  ['ADAUSDT', 'BNBUSDT', 'BTCUSDT', 'EOSUSDT', 'ETCUSDT', 'ETHUSDT', 'ICXUSDT', 'IOTAUSDT', 'LINKUSDT', 'LTCUSDT', 'NEOUSDT', 'NULSUSDT', 'ONTUSDT', 'QTUMUSDT', 'TRXUSDT', 'TUSDUSDT', 'USDCUSDT', 'VETUSDT', 'XLMUSDT', 'XRPUSDT']

# %%
# remove duplicates
duplicates = data.index.duplicated()
print(data[duplicates].index.unique('symbol'))
data = data[~data.index.duplicated()]
data.info()
# Out:
# Index(['EOSUSDT', 'ETHUSDT', 'USDCUSDT'], dtype='object', name='symbol')
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135380 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Open          135380 non-null  float64
#  1   High          135380 non-null  float64
#  2   Low           135380 non-null  float64
#  3   Close         135380 non-null  float64
#  4   Volume        135380 non-null  float64
#  5   id            128611 non-null  object
#  6   symbol_meta   128611 non-null  object
#  7   name          128611 non-null  object
#  8   market_cap    128611 non-null  float64
#  9   total_volume  128611 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 10.8+ MB

# %%
by_symbol = data.groupby(level='symbol')

# %%
# Forward returns
T = [1, 2, 3, 4, 5, 12, 24, 48, 72]
for t in T:
    data[f'ret_{t:02}'] = - by_symbol.Close.pct_change(-t)

# %%
# Backward returns (pct change)
T = [1, 2, 3, 4, 5, 12, 24, 48, 72]
for t in T:
    data[f'change_{t:02}'] = by_symbol.Close.pct_change(t)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135380 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Open          135380 non-null  float64
#  1   High          135380 non-null  float64
#  2   Low           135380 non-null  float64
#  3   Close         135380 non-null  float64
#  4   Volume        135380 non-null  float64
#  5   id            128611 non-null  object
#  6   symbol_meta   128611 non-null  object
#  7   name          128611 non-null  object
#  8   market_cap    128611 non-null  float64
#  9   total_volume  128611 non-null  float64
#  10  ret_01        135360 non-null  float64
#  11  ret_02        135340 non-null  float64
#  12  ret_03        135320 non-null  float64
#  13  ret_04        135300 non-null  float64
#  14  ret_05        135280 non-null  float64
#  15  ret_12        135140 non-null  float64
#  16  ret_24        134900 non-null  float64
#  17  ret_48        134420 non-null  float64
#  18  ret_72        133940 non-null  float64
#  19  change_01     135360 non-null  float64
#  20  change_02     135340 non-null  float64
#  21  change_03     135320 non-null  float64
#  22  change_04     135300 non-null  float64
#  23  change_05     135280 non-null  float64
#  24  change_12     135140 non-null  float64
#  25  change_24     134900 non-null  float64
#  26  change_48     134420 non-null  float64
#  27  change_72     133940 non-null  float64
# dtypes: float64(25), object(3)
# memory usage: 29.4+ MB

# %%
o = data.Open.unstack('symbol')
h = data.High.unstack('symbol')
l = data.Low.unstack('symbol')
c = data.Close.unstack('symbol')
v = data.Volume.unstack('symbol')
vwap = o.add(h).add(l).add(c).div(4)
adv20 = v.rolling(20).mean()
r = data.change_01.unstack('symbol') # return/change over the last window

# %% [markdown]
# ### Alpha 073

# %%
alpha = 73

# %%
def alpha073(l, vwap):
    """(max(rank(ts_weighted_mean(ts_delta(vwap, 4.72775), 2.91864)),
        ts_rank(ts_weighted_mean(((ts_delta(((open * 0.147155) + 
            (low * (1 - 0.147155))), 2.03608) / 
            ((open *0.147155) + (low * (1 - 0.147155)))) * -1), 3.33829), 16.7411)) * -1)
        """
    w = 0.147155
    s1 = rank(ts_weighted_mean(ts_delta(vwap, 5), 3))
    s2 = (ts_rank(ts_weighted_mean(ts_delta(o.mul(w).add(l.mul(1 - w)), 2)
                                   .div(o.mul(w).add(l.mul(1 - w)).mul(-1)), 3), 16))

    print(s2)
    return (s1.where(s1 > s2, s2)
            .mul(-1)
            .stack('symbol')
            .swaplevel())

# %%
ret_col = [c for c in data.columns if 'ret_' in c] + ['Close']
alphas = data[ret_col].copy()
alphas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135380 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ret_01  135360 non-null  float64
#  1   ret_02  135340 non-null  float64
#  2   ret_03  135320 non-null  float64
#  3   ret_04  135300 non-null  float64
#  4   ret_05  135280 non-null  float64
#  5   ret_12  135140 non-null  float64
#  6   ret_24  134900 non-null  float64
#  7   ret_48  134420 non-null  float64
#  8   ret_72  133940 non-null  float64
#  9   Close   135380 non-null  float64
# dtypes: float64(10)
# memory usage: 10.8+ MB

# %%
# %%time
alphas[f'{alpha:03}'] = alpha073(l, vwap)
# Out:
# symbol                     ADAUSDT  BNBUSDT  BTCUSDT  EOSUSDT  ETCUSDT  \
# Date
# 2024-07-01 00:00:00+00:00      NaN      NaN      NaN      NaN      NaN
# 2024-07-01 01:00:00+00:00      NaN      NaN      NaN      NaN      NaN
# 2024-07-01 02:00:00+00:00      NaN      NaN      NaN      NaN      NaN
# 2024-07-01 03:00:00+00:00      NaN      NaN      NaN      NaN      NaN
# 2024-07-01 04:00:00+00:00      NaN      NaN      NaN      NaN      NaN
# ...                            ...      ...      ...      ...      ...
# 2025-04-08 20:00:00+00:00    12.00     8.00    11.00    13.00     7.00
# 2025-04-08 21:00:00+00:00     9.00     3.00     3.00    11.00     5.00
# 2025-04-08 22:00:00+00:00     8.00     3.00     5.00     9.00     5.00
# 2025-04-08 23:00:00+00:00     6.00    10.00     7.00     9.00     6.00
# 2025-04-09 00:00:00+00:00     6.00    12.00    11.00     9.00     6.00
#
# symbol                     ETHUSDT  ICXUSDT  IOTAUSDT  LINKUSDT  LTCUSDT  \
# Date
# 2024-07-01 00:00:00+00:00      NaN      NaN       NaN       NaN      NaN
# 2024-07-01 01:00:00+00:00      NaN      NaN       NaN       NaN      NaN
# 2024-07-01 02:00:00+00:00      NaN      NaN       NaN       NaN      NaN
# 2024-07-01 03:00:00+00:00      NaN      NaN       NaN       NaN      NaN
# 2024-07-01 04:00:00+00:00      NaN      NaN       NaN       NaN      NaN
# ...                            ...      ...       ...       ...      ...
# 2025-04-08 20:00:00+00:00     7.00    11.00      6.00     11.00     9.00
# 2025-04-08 21:00:00+00:00     4.00     6.00      9.00      8.00     5.00
# 2025-04-08 22:00:00+00:00     6.00    11.00     11.00      6.00     5.00
# 2025-04-08 23:00:00+00:00     6.00    10.00     10.00      5.00     8.00
# 2025-04-09 00:00:00+00:00     1.00     5.00      8.00      5.00    10.00
#
# symbol                     NEOUSDT  NULSUSDT  ONTUSDT  QTUMUSDT  TRXUSDT  \
# Date
# 2024-07-01 00:00:00+00:00      NaN       NaN      NaN       NaN      NaN
# 2024-07-01 01:00:00+00:00      NaN       NaN      NaN       NaN      NaN
# 2024-07-01 02:00:00+00:00      NaN       NaN      NaN       NaN      NaN
# 2024-07-01 03:00:00+00:00      NaN       NaN      NaN       NaN      NaN
# 2024-07-01 04:00:00+00:00      NaN       NaN      NaN       NaN      NaN
# ...                            ...       ...      ...       ...      ...
# 2025-04-08 20:00:00+00:00     4.00      7.00     7.00     10.00    11.00
# 2025-04-08 21:00:00+00:00     4.00     11.00     6.00      5.00     9.00
# 2025-04-08 22:00:00+00:00    13.00      9.00    10.00      4.00    10.00
# 2025-04-08 23:00:00+00:00    16.00      9.00    11.00      8.00    10.00
# 2025-04-09 00:00:00+00:00    10.00     14.00    11.00      9.00    10.00
#
# symbol                     TUSDUSDT  USDCUSDT  VETUSDT  XLMUSDT  XRPUSDT
# Date
# 2024-07-01 00:00:00+00:00       NaN       NaN      NaN      NaN      NaN
# 2024-07-01 01:00:00+00:00       NaN       NaN      NaN      NaN      NaN
# 2024-07-01 02:00:00+00:00       NaN       NaN      NaN      NaN      NaN
# 2024-07-01 03:00:00+00:00       NaN       NaN      NaN      NaN      NaN
# 2024-07-01 04:00:00+00:00       NaN       NaN      NaN      NaN      NaN
# ...                             ...       ...      ...      ...      ...
# 2025-04-08 20:00:00+00:00     15.50      3.00     9.00     9.00     9.00
# 2025-04-08 21:00:00+00:00     13.50      4.00     8.00     6.00     8.00
# 2025-04-08 22:00:00+00:00      8.00      7.00     6.00     7.00    12.00
# 2025-04-08 23:00:00+00:00      4.50      9.00     6.00     9.00    10.00
# 2025-04-09 00:00:00+00:00      4.50     10.00     8.00    11.00     7.00
#
# [6769 rows x 20 columns]

# %%
alphas.dropna(inplace=True)

# %%
alphas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 133640 entries, ('ADAUSDT', Timestamp('2024-07-01 15:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-06 00:00:00+0000', tz='UTC'))
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ret_01  133640 non-null  float64
#  1   ret_02  133640 non-null  float64
#  2   ret_03  133640 non-null  float64
#  3   ret_04  133640 non-null  float64
#  4   ret_05  133640 non-null  float64
#  5   ret_12  133640 non-null  float64
#  6   ret_24  133640 non-null  float64
#  7   ret_48  133640 non-null  float64
#  8   ret_72  133640 non-null  float64
#  9   Close   133640 non-null  float64
#  10  073     133640 non-null  float64
# dtypes: float64(11)
# memory usage: 11.7+ MB

# %%
alphas[f"{alpha:003}"].describe()
# Out:
# count   133,640.00
# mean         -8.60
# std           4.81
# min         -16.00
# 25%         -13.00
# 50%          -9.00
# 75%          -4.00
# max          -1.00
# Name: 073, dtype: float64

# %% [markdown]
# #### Alpha trend visualization

# %%
# 假设数据已经在 df 中
symbols = ['BTCUSDT', 'ETHUSDT', 'XRPUSDT']

# 随机选取3个24小时的时间段
np.random.seed(42)
timestamps = alphas.index.get_level_values('Date').unique()
start_indices = np.random.choice(len(timestamps) - 24, size=3, replace=False)

time_ranges = [(timestamps[i], timestamps[i+23]) for i in start_indices]

# 开始绘图
for symbol in symbols:
    fig, axs = plt.subplots(3, 1, figsize=(8, 6), sharex=False)
    fig.suptitle(f'{symbol} - alpha{alpha:03} vs Close', fontsize=16)

    for idx, (start, end) in enumerate(time_ranges):
        temp_df = alphas.loc[symbol].loc[start:end]

        ax1 = axs[idx]
        ax1.plot(temp_df.index, temp_df[f'{alpha:03}'], label=f'alpha{alpha:03}', color='tab:blue', marker='o')
        ax1.set_ylabel(f'alpha{alpha:03}', color='tab:blue')
        ax1.tick_params(axis='y', labelcolor='tab:blue')

        ax2 = ax1.twinx()
        ax2.plot(temp_df.index, temp_df['Close'], label='Close', color='tab:red', marker='x')
        ax2.set_ylabel('Close', color='tab:red')
        ax2.tick_params(axis='y', labelcolor='tab:red')

        ax1.set_title(f'Time range: {start.strftime("%Y-%m-%d %H:%M")} - {end.strftime("%Y-%m-%d %H:%M")}', fontsize=12)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# #### Distribution visualization

# %%
sns.histplot(alphas[f"{alpha:03}"])
# Out:
# <Axes: xlabel='073', ylabel='Count'>

# %%
g = sns.jointplot(x=f"{alpha:03}", y='ret_01', data=alphas)

# %% [markdown]
# #### Correlation with future return

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", alphas[f"{alpha:03}"].corr(alphas[c]))
# Out:
# Corr between alpha073 and ret_01 is: -0.014358705417091985
# Corr between alpha073 and ret_02 is: -0.01687562578446028
# Corr between alpha073 and ret_03 is: -0.01496046757960388
# Corr between alpha073 and ret_04 is: -0.016917071026354688
# Corr between alpha073 and ret_05 is: -0.020916838985120444
# Corr between alpha073 and ret_12 is: -0.022865501396225167
# Corr between alpha073 and ret_24 is: -0.019858558080206545
# Corr between alpha073 and ret_48 is: -0.007159671550857995
# Corr between alpha073 and ret_72 is: -0.004345565185331135
# Corr between alpha073 and Close is: -0.001024984643352814

# %%
analysis_cols = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72', f'{alpha:03}']

# 初始化一个空的DataFrame用于存储每个币种的相关系数
symbols = alphas.index.get_level_values('symbol').unique()
correlation_results = pd.DataFrame(index=['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72'], 
                                   columns=symbols)

# 逐个币种计算相关系数
for symbol in symbols:
    temp_df = alphas.loc[symbol, analysis_cols].dropna()
    correlations = temp_df.corr()[f'{alpha:03}'].drop(f'{alpha:03}')
    correlation_results[symbol] = correlations

# 可视化热力图
plt.figure(figsize=(12, 7))
sns.heatmap(correlation_results.astype(float), annot=True, cmap='coolwarm', center=0)
plt.title(f'Correlation between Alpha{alpha:03} and Future Returns by Crypto')
plt.xlabel('Crypto Symbol')
plt.ylabel('Return Period')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Regression

# %%
X = sm.add_constant(alphas[f"{alpha:03}"])
model = sm.OLS(alphas['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     27.56
# Date:                Thu, 12 Jun 2025   Prob (F-statistic):           1.53e-07
# Time:                        10:33:29   Log-Likelihood:             4.2410e+05
# No. Observations:              133640   AIC:                        -8.482e+05
# Df Residuals:                  133638   BIC:                        -8.482e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003   5.68e-05     -5.587      0.000      -0.000      -0.000
# 073        -3.025e-05   5.76e-06     -5.250      0.000   -4.15e-05    -1.9e-05
# ==============================================================================
# Omnibus:                    40492.960   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6636573.577
# Skew:                           0.206   Prob(JB):                         0.00
# Kurtosis:                      37.521   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
residuals = model.resid

# 1. 绘制直方图和 KDE 曲线
plt.figure(figsize=(10,6))
sns.histplot(residuals, bins=30, kde=True)
plt.xlabel("Residuals")
plt.title("Distribution of Model Residuals")
plt.show()

# 2. 绘制 Q-Q 图，检查正态性
sm.qqplot(residuals, line='s')
plt.title("Q-Q Plot of Model Residuals")
plt.show()

# %% [markdown]
# ### Evaluation for BTC

# %%
btc_data = alphas.loc['BTCUSDT']
btc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6682 entries, 2024-07-01 15:00:00+00:00 to 2025-04-06 00:00:00+00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ret_01  6682 non-null   float64
#  1   ret_02  6682 non-null   float64
#  2   ret_03  6682 non-null   float64
#  3   ret_04  6682 non-null   float64
#  4   ret_05  6682 non-null   float64
#  5   ret_12  6682 non-null   float64
#  6   ret_24  6682 non-null   float64
#  7   ret_48  6682 non-null   float64
#  8   ret_72  6682 non-null   float64
#  9   Close   6682 non-null   float64
#  10  073     6682 non-null   float64
# dtypes: float64(11)
# memory usage: 626.4 KB

# %%
sns.histplot(btc_data[f"{alpha:03}"])
# Out:
# <Axes: xlabel='073', ylabel='Count'>

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", btc_data[f"{alpha:03}"].corr(btc_data[c]))
# Out:
# Corr between alpha073 and ret_01 is: -0.01387519969705072
# Corr between alpha073 and ret_02 is: -0.02173600817928767
# Corr between alpha073 and ret_03 is: -0.023131108933219263
# Corr between alpha073 and ret_04 is: -0.026401530813207306
# Corr between alpha073 and ret_05 is: -0.02448531249689172
# Corr between alpha073 and ret_12 is: -0.007924717427075924
# Corr between alpha073 and ret_24 is: -0.01818174509493425
# Corr between alpha073 and ret_48 is: -0.006510701646196427
# Corr between alpha073 and ret_72 is: -0.0002513792090075084
# Corr between alpha073 and Close is: -0.004716428122250522

# %%
btc_data.index = pd.to_datetime(btc_data.index)

# 创建月份的分组标签（格式如 '2024-07'）
btc_data['month'] = btc_data.index.to_period('M').astype(str)

# 需要分析的收益列
ret_columns = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72']

# 初始化一个DataFrame用于存储相关性结果
months = sorted(btc_data['month'].unique())
correlation_matrix = pd.DataFrame(index=ret_columns, columns=months)

# 按月份计算相关性
for month in months:
    temp_df = btc_data[btc_data['month'] == month]
    for ret in ret_columns:
        corr_value = temp_df[[f'{alpha:03}', ret]].corr().iloc[0, 1]
        correlation_matrix.loc[ret, month] = corr_value

# 转换数据类型为float，方便绘图
correlation_matrix = correlation_matrix.astype(float)

# 使用heatmap可视化
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title(f'Monthly Correlation between Alpha{alpha:03} and Returns for BTC', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Return Columns', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_1116\1316720417.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   btc_data['month'] = btc_data.index.to_period('M').astype(str)
# C:\Users\elisa\AppData\Local\Temp\ipykernel_1116\1316720417.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   btc_data['month'] = btc_data.index.to_period('M').astype(str)

# %%
X = sm.add_constant(btc_data[f"{alpha:03}"])
model = sm.OLS(btc_data['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.286
# Date:                Thu, 12 Jun 2025   Prob (F-statistic):              0.257
# Time:                        10:33:31   Log-Likelihood:                 24956.
# No. Observations:                6682   AIC:                        -4.991e+04
# Df Residuals:                    6680   BIC:                        -4.989e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.000     -0.817      0.414      -0.000       0.000
# 073        -1.663e-05   1.47e-05     -1.134      0.257   -4.54e-05    1.21e-05
# ==============================================================================
# Omnibus:                     1143.897   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21021.294
# Skew:                          -0.246   Prob(JB):                         0.00
# Kurtosis:                      11.675   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Evaluation for ETH

# %%
eth_data = alphas.loc['ETHUSDT']
eth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6682 entries, 2024-07-01 15:00:00+00:00 to 2025-04-06 00:00:00+00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ret_01  6682 non-null   float64
#  1   ret_02  6682 non-null   float64
#  2   ret_03  6682 non-null   float64
#  3   ret_04  6682 non-null   float64
#  4   ret_05  6682 non-null   float64
#  5   ret_12  6682 non-null   float64
#  6   ret_24  6682 non-null   float64
#  7   ret_48  6682 non-null   float64
#  8   ret_72  6682 non-null   float64
#  9   Close   6682 non-null   float64
#  10  073     6682 non-null   float64
# dtypes: float64(11)
# memory usage: 626.4 KB

# %%
sns.histplot(eth_data[f"{alpha:03}"])
# Out:
# <Axes: xlabel='073', ylabel='Count'>

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", eth_data[f"{alpha:03}"].corr(eth_data[c]))
# Out:
# Corr between alpha073 and ret_01 is: -0.002188712691935534
# Corr between alpha073 and ret_02 is: 0.0009202105011726911
# Corr between alpha073 and ret_03 is: 0.0028316055814796423
# Corr between alpha073 and ret_04 is: 0.002217297931504835
# Corr between alpha073 and ret_05 is: 0.00038469728457127245
# Corr between alpha073 and ret_12 is: 0.009745672551239528
# Corr between alpha073 and ret_24 is: -0.030269918936016226
# Corr between alpha073 and ret_48 is: -0.01208520101663025
# Corr between alpha073 and ret_72 is: -0.0011471043911577658
# Corr between alpha073 and Close is: 0.008267460755015039

# %%
eth_data.index = pd.to_datetime(eth_data.index)

# 创建月份的分组标签（格式如 '2024-07'）
eth_data['month'] = eth_data.index.to_period('M').astype(str)

# 需要分析的收益列
ret_columns = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72']

# 初始化一个DataFrame用于存储相关性结果
months = sorted(eth_data['month'].unique())
correlation_matrix = pd.DataFrame(index=ret_columns, columns=months)

# 按月份计算相关性
for month in months:
    temp_df = eth_data[eth_data['month'] == month]
    for ret in ret_columns:
        corr_value = temp_df[[f"{alpha:003}", ret]].corr().iloc[0, 1]
        correlation_matrix.loc[ret, month] = corr_value

# 转换数据类型为float，方便绘图
correlation_matrix = correlation_matrix.astype(float)

# 使用heatmap可视化
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title(f'Monthly Correlation between Alpha{alpha:003} and Returns for ETH', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Return Columns', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_1116\3977908595.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   eth_data['month'] = eth_data.index.to_period('M').astype(str)
# C:\Users\elisa\AppData\Local\Temp\ipykernel_1116\3977908595.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_data['month'] = eth_data.index.to_period('M').astype(str)

# %%
X = sm.add_constant(eth_data[f"{alpha:03}"])
model = sm.OLS(eth_data['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.03200
# Date:                Thu, 12 Jun 2025   Prob (F-statistic):              0.858
# Time:                        10:33:31   Log-Likelihood:                 23007.
# No. Observations:                6682   AIC:                        -4.601e+04
# Df Residuals:                    6680   BIC:                        -4.600e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.813      0.416      -0.001       0.000
# 073        -3.502e-06   1.96e-05     -0.179      0.858   -4.19e-05    3.49e-05
# ==============================================================================
# Omnibus:                     2873.951   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           162793.890
# Skew:                          -1.264   Prob(JB):                         0.00
# Kurtosis:                      27.048   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Evaluation for ADA

# %%
ada_data = alphas.loc['ADAUSDT']
ada_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6682 entries, 2024-07-01 15:00:00+00:00 to 2025-04-06 00:00:00+00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ret_01  6682 non-null   float64
#  1   ret_02  6682 non-null   float64
#  2   ret_03  6682 non-null   float64
#  3   ret_04  6682 non-null   float64
#  4   ret_05  6682 non-null   float64
#  5   ret_12  6682 non-null   float64
#  6   ret_24  6682 non-null   float64
#  7   ret_48  6682 non-null   float64
#  8   ret_72  6682 non-null   float64
#  9   Close   6682 non-null   float64
#  10  073     6682 non-null   float64
# dtypes: float64(11)
# memory usage: 626.4 KB

# %%
sns.histplot(ada_data[f"{alpha:03}"])
# Out:
# <Axes: xlabel='073', ylabel='Count'>

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", ada_data[f"{alpha:03}"].corr(ada_data[c]))
# Out:
# Corr between alpha073 and ret_01 is: -0.021401605739567797
# Corr between alpha073 and ret_02 is: -0.020130504332938365
# Corr between alpha073 and ret_03 is: -0.01573644205688925
# Corr between alpha073 and ret_04 is: -0.01596570440099641
# Corr between alpha073 and ret_05 is: -0.01711271480850335
# Corr between alpha073 and ret_12 is: -0.014644852398981556
# Corr between alpha073 and ret_24 is: -0.015766925565859412
# Corr between alpha073 and ret_48 is: -0.014119149262331336
# Corr between alpha073 and ret_72 is: -0.004195623697414632
# Corr between alpha073 and Close is: 0.0031613840337209307

# %%
ada_data.index = pd.to_datetime(ada_data.index)

# 创建月份的分组标签（格式如 '2024-07'）
ada_data['month'] = ada_data.index.to_period('M').astype(str)

# 需要分析的收益列
ret_columns = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72']

# 初始化一个DataFrame用于存储相关性结果
months = sorted(ada_data['month'].unique())
correlation_matrix = pd.DataFrame(index=ret_columns, columns=months)

# 按月份计算相关性
for month in months:
    temp_df = ada_data[ada_data['month'] == month]
    for ret in ret_columns:
        corr_value = temp_df[[f"{alpha:003}", ret]].corr().iloc[0, 1]
        correlation_matrix.loc[ret, month] = corr_value

# 转换数据类型为float，方便绘图
correlation_matrix = correlation_matrix.astype(float)

# 使用heatmap可视化
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title(f'Monthly Correlation between Alpha{alpha:003} and Returns for ADA', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Return Columns', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_1116\2821918388.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   ada_data['month'] = ada_data.index.to_period('M').astype(str)
# C:\Users\elisa\AppData\Local\Temp\ipykernel_1116\2821918388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ada_data['month'] = ada_data.index.to_period('M').astype(str)

# %%
X = sm.add_constant(ada_data[f"{alpha:03}"])
model = sm.OLS(ada_data['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.061
# Date:                Thu, 12 Jun 2025   Prob (F-statistic):             0.0802
# Time:                        10:33:32   Log-Likelihood:                 19863.
# No. Observations:                6682   AIC:                        -3.972e+04
# Df Residuals:                    6680   BIC:                        -3.971e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.000     -1.547      0.122      -0.001       0.000
# 073        -5.525e-05   3.16e-05     -1.750      0.080      -0.000    6.65e-06
# ==============================================================================
# Omnibus:                     2577.644   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           726185.794
# Skew:                           0.587   Prob(JB):                         0.00
# Kurtosis:                      54.058   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
